# %% [markdown]
# 將Google雲端硬碟掛載到Colab環境中的
# '/content/drive'路徑

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 更改當前工作目錄

# %%
# %cd /content/drive/MyDrive/Github
# Out:
# /content/drive/MyDrive/Github

# %% [markdown]
# 版本控制
# 安裝

# %%
# !apt-get install git
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git is already the newest version (1:2.25.1-1ubuntu3.11).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.

# %% [markdown]
# 初始化一個本地git儲存庫

# %%
# !git init Notebook-Price-and-Specifications
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Github/Notebook-Price-and-Specifications/.git/

# %%
# %cd Notebook-Price-and-Specifications/
# Out:
# /content/drive/MyDrive/Github/Notebook-Price-and-Specifications

# %%
# %ls -a
# Out:
# .git/

# %%
# !git status
# Out:
# On branch master
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git add .

# %%
# !git status
# Out:
# On branch master
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %% [markdown]
# 配置

# %%
# !git config --global user.name "Hsu-Linda"
# !git config --global user.email "lindasandy2835@gmail.com"
# !git config --global user.password "chihLittleBird1001"

# %% [markdown]
# 告訴git儲存庫 遠程儲存庫i.e.github
# 設置一個名為origin的地址 URL

# %%
# !git remote add origin https://github.com/Hsu-Linda/Notebook-Price-and-Specifications.git

# %% [markdown]
# 如果你想將 Colab 中的筆記本檔案加入到版本控制中，你可以遵循以下步驟

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# 將筆記本添加到git版本控制

# %%
os.listdir()
# Out:
# ['.config', '.git', 'sample_data']

# %%
# !git add notebook_price_spider.ipynb
# Out:
# fatal: pathspec 'notebook_price_spider.ipynb' did not match any files

# %%
# !ls
# Out:
# sample_data
